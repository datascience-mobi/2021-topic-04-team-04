# %%
import scipy.ndimage

from Functions import image_processing as ip
import skimage.io as sk
import numpy as np
import matplotlib.pyplot as plt
from scipy import ndimage, misc

sudo apt-get install libboost-python-dev build-essential
sudo pip install medpy
import medpy
from medpy.filter.smoothing import anisotropic_diffusion
# Out:
#   File "<ipython-input-98-2ce7858b21b4>", line 9
#     pip3 install medpy
#          ^
# SyntaxError: invalid syntax

# %%
image = sk.imread("Data/N2DH-GOWT1/img/t01.tif")
ip.show_image(image, 15, 8)

# %%
ip.histogram(image)

# %%
img_clipped = ip.image_clipping(image, 5, 25)
ip.show_image(img_clipped, 15, 8)

# %%
image2 = sk.imread("Data/NIH3T3/img/dna-33.png")
ip.show_image(image2, 15, 8)

# %%
ip.histogram(image2)

# %%
test1 = ip.remove_bright_spots(image2, 110)
ip.show_image(test1, 15, 8)

# %%
test2 = ip.median_filter(image, 20)
ip.show_image(test2, 15, 8)

# %%
test3 = ip.mean_filter(image, 20)
ip.show_image(test3, 15, 8)

# %%
test4 = ip.gaussian_filter(image, 5)
ip.show_image(test4, 15, 8)

# %%
def anisotropic_filter(img):
    img_copy = img.copy()
    img_anisotropic = anisotropic_diffusion(img.flatten())
    return img_anisotropic

# %%
test5 = anisotropic_filter(image)
ip.show_image(test5, 15, 8)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-81-2134bddcee04> in <module>
# ----> 1 test5 = anisotropic_filter(image)
#       2 ip.show_image(test5, 15, 8)
#       3
#
# <ipython-input-80-ea155870b841> in anisotropic_filter(img)
#       1 def anisotropic_filter(img):
#       2     img_copy = img.copy()
# ----> 3     img_anisotropic = anisotropic_diffusion(img.flatten())
#       4     return img_anisotropic
#       5
#
# NameError: name 'anisotropic_diffusion' is not defined
