# %% [markdown]
# Laden eines Bildes über Github

# %%
# %pylab
# %matplotlib inline

img = imread("../Data/NIH3T3/img/dna-1.png")
imshow(img, "gray")
# Out:
# Using matplotlib backend: Qt5Agg
# Populating the interactive namespace from numpy and matplotlib

# %%
flat = img.flatten()
hist(flat)
# Out:
# (array([1.130069e+06, 1.031600e+05, 9.477800e+04, 3.597800e+04,
#         9.084000e+03, 2.484000e+03, 5.750000e+02, 8.500000e+01,
#         3.000000e+01, 1.300000e+01]),
#  array([0.07450981, 0.10156863, 0.12862745, 0.15568627, 0.1827451 ,
#         0.20980392, 0.23686275, 0.2639216 , 0.2909804 , 0.31803924,
#         0.34509805], dtype=float32),
#  <BarContainer object of 10 artists>)

# %%
T1 = 1
v1 = 0.20
img5 = img.copy()
obj = ndindex(img.shape) # gibt für jedes Pizel ein Tupel mit (Reihe, Spalte)
for i in obj:
    if img[i] > v1:
        img5[i] = T1

imshow(img5, "gray")

# %%
import skimage.io

img2 = skimage.io.imread("../Data/N2DH-GOWT1/img/t01.tif")
imshow(img2, "gray")

# %% [markdown]
# Test Ground Truth Clippen

# %%
img2_gt = skimage.io.imread("../Data/N2DH-GOWT1/gt/man_seg01.tif")
imshow(img2_gt, "gray")

# %%
from Functions import functions as f

img_new_gt = img2_gt.copy()
for i in ndindex(img2_gt.shape):
    if img2_gt[i] != 0:
        img_new_gt[i] = 5

f.show_image(img_new_gt, 15, 8)

# %%
f.show_image(img2, 15, 8)

# %%
import PIL
from PIL import Image
im = Image.fromarray(img_new_gt)
im.save("new_gt.tif")
